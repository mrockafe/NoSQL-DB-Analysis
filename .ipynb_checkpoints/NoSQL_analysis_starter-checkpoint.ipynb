# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': {'$eq': 20}}

# Use count_documents to display the number of documents in the result
results = establishments.count_documents(query)

print(f"The total number of establishments with a hygiene score of 20 is: {results}")

print("______________________________________________________________________")

# Display the first document in the results using pprint
establishment = establishments.find_one(query)
pprint(establishment)
# Out:
# The total number of establishments with a hygiene score of 20 is: 41
# ______________________________________________________________________
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f4b1c3fe66c588048433da'),
# ...

# %%
# Convert the result to a Pandas DataFrame
hygine20 = establishments.find(query)

hygine_df = pd.DataFrame(list(hygine20))

# Display the number of rows in the DataFrame
print(f"There are {len(hygine_df)} rows in the dataframe.")

print("---------------------------------------------------")

# Display the first 10 rows of the DataFrame
hygine_df.head(10)
# Out:
# There are 41 rows in the dataframe.
# ---------------------------------------------------
#                         _id   FHRSID  ChangesByServerID  \
# 0  64f4b1c3fe66c588048433da   110681                  0
# 1  64f4b1c3fe66c5880484376d   612039                  0
# 2  64f4b1c3fe66c58804843a65   730933                  0
# 3  64f4b1c3fe66c58804843c52   172735                  0
# 4  64f4b1c3fe66c58804843c60   172953                  0
# 5  64f4b1c3fe66c588048445ff   512854                  0
# 6  64f4b1c3fe66c58804844821  1537089                  0
# 7  64f4b1c3fe66c58804845d4f   155648                  0
# 8  64f4b1c3fe66c58804846191  1012883                  0
# 9  64f4b1c3fe66c588048469a6   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'RatingValue': {'$gte': 4}}

# Use count_documents to display the number of documents in the result
ratings4 = establishments.count_documents(query)
print(f"The total number of establishments with a 'Rating Value' score of 4 or higher is: {ratings4}")
print("____________________________________________________________________________________________")

# Display the first document in the results using pprint
establishment = establishments.find_one(query)
pprint(establishment)
# Out:
# The total number of establishments with a 'Rating Value' score of 4 or higher is: 31257
# ____________________________________________________________________________________________
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
# ...

# %%
# Convert the result to a Pandas DataFrame
ratings4 = establishments.find(query)
ratings_df = pd.DataFrame(list(ratings4))

# Display the number of rows in the DataFrame
print(f"There are {len(ratings_df)} rows in the dataframe.")

print("---------------------------------------------------")

# Display the first 10 rows of the DataFrame
ratings_df.head(10)
# Out:
# There are 31257 rows in the dataframe.
# ---------------------------------------------------
#                         _id   FHRSID  ChangesByServerID  \
# 0  64f4b1c3fe66c588048418a6  1043695                  0
# 1  64f4b1c3fe66c588048418a7   647177                  0
# 2  64f4b1c3fe66c588048418a8   289353                  0
# 3  64f4b1c3fe66c588048418ab   289560                  0
# 4  64f4b1c3fe66c588048418ac   344689                  0
# 5  64f4b1c3fe66c588048418ad   987206                  0
# 6  64f4b1c3fe66c588048418ae   894592                  0
# 7  64f4b1c3fe66c588048418af  1043701                  0
# 8  64f4b1c3fe66c588048418b0   289352                  0
# 9  64f4b1c3fe66c588048418b1   805703                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000073616                         The Pavilion
# 1             PI/000041489                  Wear Bay Bowls Club
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.4934
longitude = 0.0098

query = {
    'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search},
    'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search},
    'RatingValue': 5
}

sort = [('scores.Hygiene', 1)]
limit = 5

step3 = establishments.find(query).sort(sort).limit(limit)

# Print the results
for doc in step3:
    pprint(doc)
# Out:
# {'AddressLine1': 'Unit 2 12 Horn Lane',
#  'AddressLine2': '',
#  'AddressLine3': 'Greenwich',
#  'AddressLine4': '',
#  'BusinessName': 'From Origin',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4649.646401159161,
#  'FHRSID': 1319364,
#  'LocalAuthorityBusinessID': '14034',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE10 0RT',
#  'RatingDate': '2021-03-22T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64f4b1c4fe66c588048498da'),
#  'geocode': {'latitude': Decimal128('51.4869924000000'),
#              'longitude': Decimal128('0.0182414000000000')},
# ...

# %%
# Convert result to Pandas DataFrame
step3 = establishments.find(query)
solved_df = pd.DataFrame(step3)

solved_df.head(5)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64f4b1c4fe66c58804849892  1255582                  0
# 1  64f4b1c4fe66c5880484989a   694751                  0
# 2  64f4b1c4fe66c5880484989b   695050                  0
# 3  64f4b1c4fe66c588048498da  1319364                  0
# 4  64f4b1c4fe66c588048498dd   695486                  0
#
#   LocalAuthorityBusinessID      BusinessName             BusinessType  \
# 0                    13514    Venezia Coffee  Restaurant/Cafe/Canteen
# 1             PI/000139666    Royal Nepalese  Restaurant/Cafe/Canteen
# 2             PI/000174142     The Coriander  Restaurant/Cafe/Canteen
# 3                    14034       From Origin  Other catering premises
# 4             PI/000186740  Angerstein Hotel        Pub/bar/nightclub
#
#    BusinessTypeID                                       AddressLine1  \
# 0               1  Ticket Office Westcombe Park Station Station C...
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene': {'$eq': 0}}}

# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id': "$LocalAuthorityName", 'count': { '$sum': 1 }}}

# 3. Sorts the matches from highest to lowest
sort_values = {'$sort': { 'count': -1 }}

combined = [match_query, group_query, sort_values]
solved = list(establishments.aggregate(combined))

# Print the number of documents in the result
print("Number of documents in the results: ", len(solved))

# Print the first 10 results
pprint(solved[0:10])
# Out:
# Number of documents in the results:  55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
step4_df = pd.DataFrame(solved)

# Display the number of rows in the DataFrame
print(f"There are {len(step4_df)} rows")

# Display the first 10 rows of the DataFrame
step4_df.head(10)
# Out:
# There are 55 rows
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
